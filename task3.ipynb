# %%
import networkx as nx
# %matplotlib inline

# %%
G = nx.Graph()

G.add_nodes_from([1, 2, 3, 4])

G.add_edges_from([(1, 2), (2, 3), (1, 3), (1, 4)])

nx.draw(G, with_labels=True)

# %%
nx.has_path(G, 3, 4)
# Out:
# True

# %%
list(nx.all_simple_paths(G, 3, 4))
# Out:
# [[3, 2, 1, 4], [3, 1, 4]]

# %%
nx.shortest_path(G, 3, 4)
# Out:
# [3, 1, 4]

# %%
nx.shortest_path_length(G, 3, 4)
# Out:
# 2

# %%
nx.is_connected(G)
# Out:
# True

# %%
G = nx.Graph()

nx.add_cycle(G,(1,2,3))
G.add_edge(4,5)

nx.draw(G, with_labels=True)

# %%
G = nx.Graph() 
nx.add_cycle(G, [0, 1, 2, 3])
nx.add_cycle(G, [10, 11, 12])
# G.add_edge(3, 10)

# %%
nx.draw(G, with_labels=True)

# %%
nx.is_connected(G)
# Out:
# False

# %%
nx.number_connected_components(G)
# Out:
# 2

# %%
list(nx.connected_components(G))
# Out:
# [{0, 1, 2, 3}, {10, 11, 12}]

# %%
components = list(nx.connected_components(G))
len(components[0])
# Out:
# 4

# %%
max(nx.connected_components(G), key=len)
# Out:
# {0, 1, 2, 3}

# %%
core_nodes = min(nx.connected_components(G), key=len)
core = G.subgraph(core_nodes)

nx.draw(core, with_labels=True)

# %%
D = nx.DiGraph()
D.add_edges_from([
    (1, 2),
    (2, 3),
    (3, 2), (3, 4), (3, 5),
    (4, 2), (4, 5), (4, 6),
    (5, 6),
    (6, 4),
])
nx.draw(D, with_labels=True)

# %%
nx.has_path(D, 1, 4)
# Out:
# True

# %%
nx.has_path(D, 4, 1)
# Out:
# False

# %%
nx.shortest_path(D, 2, 5)
# Out:
# [2, 3, 5]

# %%
nx.shortest_path(D, 5, 2)
# Out:
# [5, 6, 4, 2]

# %%
nx.is_strongly_connected(D)
# Out:
# False

# %%
nx.is_weakly_connected(D)
# Out:
# True

# %%
nx.is_connected(D)
# Out:
# ---------------------------------------------------------------------------
# NetworkXNotImplemented                    Traceback (most recent call last)
# C:\Users\MOHAME~1\AppData\Local\Temp/ipykernel_7800/1401147448.py in <module>
# ----> 1 nx.is_connected(D)
#
# ~\anaconda3\lib\site-packages\networkx\utils\decorators.py in func(_argmap__wrapper, *args, **kwargs)
#     793
#     794             def func(*args, __wrapper=None, **kwargs):
# --> 795                 return argmap._lazy_compile(__wrapper)(*args, **kwargs)
#     796
#     797         # standard function-wrapping stuff
#
# ~\anaconda3\lib\site-packages\networkx\utils\decorators.py in argmap_is_connected_9(G)
#       1 from collections import defaultdict
#       2 from os.path import splitext
# ----> 3 from contextlib import contextmanager
#       4 from pathlib import Path
#       5 import warnings
#
# ~\anaconda3\lib\site-packages\networkx\utils\decorators.py in _not_implemented_for(g)
# ...

# %%
list(nx.weakly_connected_components(D))
# Out:
# [{1, 2, 3, 4, 5, 6}]

# %%
list(nx.strongly_connected_components(D))
# Out:
# [{2, 3, 4, 5, 6}, {1}]

# %%
g = nx.read_graphml('F:/fci/social is/FirstCourseNetworkScience-master/datasets/openflights/openflights_usa.graphml.gz')

# %%
g.nodes['IND']
# Out:
# {'name': 'Indianapolis International Airport',
#  'latitude': 39.7173,
#  'longitude': -86.294403,
#  'IATA': 'IND'}

# %%
g.nodes['IND']['name']
# Out:
# 'Indianapolis International Airport'

# %%
# EXERCISE 1
nx.has_path(g,'IND' ,'FAI')
# Out:
# True

# %%
# EXERCISE 2
nx.shortest_path(g,'IND' ,'FAI')
# Out:
# ['IND', 'BOS', 'SEA', 'FAI']

# %%
# EXERCISE 3
nx.is_strongly_connected(g)
# Out:
# ---------------------------------------------------------------------------
# NetworkXNotImplemented                    Traceback (most recent call last)
# C:\Users\MOHAME~1\AppData\Local\Temp/ipykernel_7800/675227117.py in <module>
#       1 # EXERCISE 3
# ----> 2 nx.is_strongly_connected(g)
#
# ~\anaconda3\lib\site-packages\networkx\utils\decorators.py in argmap_is_strongly_connected_26(G)
#       1 from collections import defaultdict
#       2 from os.path import splitext
# ----> 3 from contextlib import contextmanager
#       4 from pathlib import Path
#       5 import warnings
#
# ~\anaconda3\lib\site-packages\networkx\utils\decorators.py in _not_implemented_for(g)
#      85             dval is None or dval == g.is_directed()
#      86         ):
# ---> 87             raise nx.NetworkXNotImplemented(errmsg)
#      88
#      89         return g
#
# NetworkXNotImplemented: not implemented for undirected type

# %%
# EXERCISE 3
nx.is_connected(g)
# Out:
# False
